# %%
import pandas as pd

# %%
data = pd.read_csv("/content/test.csv.zip")
data_test = pd.read_csv("/content/train.csv.zip")

# %%
data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
# 2           0.275485          -0.026050          -0.118152         -0.993819
# 3           0.270298          -0.032614          -0.117520         -0.994743
# 4           0.274833          -0.027848          -0.129527         -0.993852
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
# 2         -0.969926         -0.962748         -0.994403         -0.970735
# 3         -0.973268         -0.967091         -0.995274         -0.974471
# 4         -0.967445         -0.978295         -0.994111         -0.965953
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0         -0.674302         -0.894088  ...                        -0.705974
# 1         -0.945823         -0.894088  ...                        -0.594944
# 2         -0.963483         -0.939260  ...                        -0.640736
# 3         -0.968897         -0.938610  ...                        -0.736124
# 4         -0.977346         -0.938610  ...                        -0.846595
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                     0.006462                              0.162920
# 1                    -0.083495                              0.017500
# 2                    -0.034956                              0.202302
# 3                    -0.017067                              0.154438
# 4                    -0.002223                             -0.040046
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                         -0.825886                              0.271151
# 1                         -0.434375                              0.920593
# 2                          0.064103                              0.145068
# 3                          0.340134                              0.296407
# 4                          0.736715                             -0.118545
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  subject  \
# 0             -0.720009              0.276801             -0.057978        2
# 1             -0.698091              0.281343             -0.083898        2
# 2             -0.702771              0.280083             -0.079346        2
# 3             -0.698954              0.284114             -0.077108        2
# 4             -0.692245              0.290722             -0.073857        2
#
#    Activity
# 0  STANDING
# 1  STANDING
# 2  STANDING
# 3  STANDING
# 4  STANDING
#
# [5 rows x 563 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_32['tBodyAcc-mean()-X'].plot(kind='hist', bins=20, title='tBodyAcc-mean()-X')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_33['tBodyAcc-mean()-Y'].plot(kind='hist', bins=20, title='tBodyAcc-mean()-Y')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_34['tBodyAcc-mean()-Z'].plot(kind='hist', bins=20, title='tBodyAcc-mean()-Z')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_35['tBodyAcc-std()-X'].plot(kind='hist', bins=20, title='tBodyAcc-std()-X')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_36.plot(kind='scatter', x='tBodyAcc-mean()-X', y='tBodyAcc-mean()-Y', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_37.plot(kind='scatter', x='tBodyAcc-mean()-Y', y='tBodyAcc-mean()-Z', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_38.plot(kind='scatter', x='tBodyAcc-mean()-Z', y='tBodyAcc-std()-X', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_39.plot(kind='scatter', x='tBodyAcc-std()-X', y='tBodyAcc-std()-Y', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['tBodyAcc-min()-X']
#   ys = series['tBodyAcc-mean()-X']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_40.sort_values('tBodyAcc-min()-X', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('tBodyAcc-min()-X')
# _ = plt.ylabel('tBodyAcc-mean()-X')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['tBodyAcc-min()-X']
#   ys = series['tBodyAcc-mean()-Y']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_41.sort_values('tBodyAcc-min()-X', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('tBodyAcc-min()-X')
# _ = plt.ylabel('tBodyAcc-mean()-Y')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['tBodyAcc-min()-X']
#   ys = series['tBodyAcc-mean()-Z']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_42.sort_values('tBodyAcc-min()-X', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('tBodyAcc-min()-X')
# _ = plt.ylabel('tBodyAcc-mean()-Z')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['tBodyAcc-min()-X']
#   ys = series['tBodyAcc-std()-X']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_43.sort_values('tBodyAcc-min()-X', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('tBodyAcc-min()-X')
# _ = plt.ylabel('tBodyAcc-std()-X')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_44['tBodyAcc-mean()-X'].plot(kind='line', figsize=(8, 4), title='tBodyAcc-mean()-X')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_45['tBodyAcc-mean()-Y'].plot(kind='line', figsize=(8, 4), title='tBodyAcc-mean()-Y')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_46['tBodyAcc-mean()-Z'].plot(kind='line', figsize=(8, 4), title='tBodyAcc-mean()-Z')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_47['tBodyAcc-std()-X'].plot(kind='line', figsize=(8, 4), title='tBodyAcc-std()-X')
# plt.gca().spines[['top', 'right']].set_visible(False)
# Warning: Total number of columns (563) exceeds max_columns (20) limiting to first (20) columns.

# %%
data.tail()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 2942           0.310155          -0.053391          -0.099109
# 2943           0.363385          -0.039214          -0.105915
# 2944           0.349966           0.030077          -0.115788
# 2945           0.237594           0.018467          -0.096499
# 2946           0.153627          -0.018437          -0.137018
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 2942         -0.287866         -0.140589         -0.215088         -0.356083
# 2943         -0.305388          0.028148         -0.196373         -0.373540
# 2944         -0.329638         -0.042143         -0.250181         -0.388017
# 2945         -0.323114         -0.229775         -0.207574         -0.392380
# 2946         -0.330046         -0.195253         -0.164339         -0.430974
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 2942         -0.148775         -0.232057          0.185361  ...
# 2943         -0.030036         -0.270237          0.185361  ...
# 2944         -0.133257         -0.347029          0.007471  ...
# 2945         -0.279610         -0.289477          0.007471  ...
# 2946         -0.218295         -0.229933         -0.111527  ...
#
#       fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 2942                        -0.750809                    -0.337422
# 2943                        -0.700274                    -0.736701
# 2944                        -0.467179                    -0.181560
# 2945                        -0.617737                     0.444558
# 2946                        -0.436940                     0.598808
#
#       angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 2942                              0.346295                          0.884904
# 2943                             -0.372889                         -0.657421
# 2944                              0.088574                          0.696663
# 2945                             -0.819188                          0.929294
# 2946                             -0.287951                          0.876030
#
#       angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 2942                             -0.698885             -0.651732
# 2943                              0.322549             -0.655181
# 2944                              0.363139             -0.655357
# 2945                             -0.008398             -0.659719
# 2946                             -0.024965             -0.660080
#
#       angle(Y,gravityMean)  angle(Z,gravityMean)  subject          Activity
# 2942              0.274627              0.184784       24  WALKING_UPSTAIRS
# 2943              0.273578              0.182412       24  WALKING_UPSTAIRS
# 2944              0.274479              0.181184       24  WALKING_UPSTAIRS
# 2945              0.264782              0.187563       24  WALKING_UPSTAIRS
# 2946              0.263936              0.188103       24  WALKING_UPSTAIRS
#
# [5 rows x 563 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_48['tBodyAcc-mean()-X'].plot(kind='hist', bins=20, title='tBodyAcc-mean()-X')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_49['tBodyAcc-mean()-Y'].plot(kind='hist', bins=20, title='tBodyAcc-mean()-Y')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_50['tBodyAcc-mean()-Z'].plot(kind='hist', bins=20, title='tBodyAcc-mean()-Z')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_51['tBodyAcc-std()-X'].plot(kind='hist', bins=20, title='tBodyAcc-std()-X')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_52.plot(kind='scatter', x='tBodyAcc-mean()-X', y='tBodyAcc-mean()-Y', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_53.plot(kind='scatter', x='tBodyAcc-mean()-Y', y='tBodyAcc-mean()-Z', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_54.plot(kind='scatter', x='tBodyAcc-mean()-Z', y='tBodyAcc-std()-X', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_55.plot(kind='scatter', x='tBodyAcc-std()-X', y='tBodyAcc-std()-Y', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['tBodyAcc-arCoeff()-Y,3']
#   ys = series['tBodyAcc-mean()-X']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_56.sort_values('tBodyAcc-arCoeff()-Y,3', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('tBodyAcc-arCoeff()-Y,3')
# _ = plt.ylabel('tBodyAcc-mean()-X')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['tBodyAcc-arCoeff()-Y,3']
#   ys = series['tBodyAcc-mean()-Y']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_57.sort_values('tBodyAcc-arCoeff()-Y,3', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('tBodyAcc-arCoeff()-Y,3')
# _ = plt.ylabel('tBodyAcc-mean()-Y')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['tBodyAcc-arCoeff()-Y,3']
#   ys = series['tBodyAcc-mean()-Z']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_58.sort_values('tBodyAcc-arCoeff()-Y,3', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('tBodyAcc-arCoeff()-Y,3')
# _ = plt.ylabel('tBodyAcc-mean()-Z')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['tBodyAcc-arCoeff()-Y,3']
#   ys = series['tBodyAcc-std()-X']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_59.sort_values('tBodyAcc-arCoeff()-Y,3', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('tBodyAcc-arCoeff()-Y,3')
# _ = plt.ylabel('tBodyAcc-std()-X')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_60['tBodyAcc-mean()-X'].plot(kind='line', figsize=(8, 4), title='tBodyAcc-mean()-X')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_61['tBodyAcc-mean()-Y'].plot(kind='line', figsize=(8, 4), title='tBodyAcc-mean()-Y')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_62['tBodyAcc-mean()-Z'].plot(kind='line', figsize=(8, 4), title='tBodyAcc-mean()-Z')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_63['tBodyAcc-std()-X'].plot(kind='line', figsize=(8, 4), title='tBodyAcc-std()-X')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
data.shape
# Out:
# (2947, 563)

# %%
print("Number of Rows",data.shape[0])
print("Number of columns",data.shape[1])
# Out:
# Number of Rows 2947
# Number of columns 563

# %%
data.duplicated().any()
# Out:
# False

# %%
duplicated_columns = data.columns[data.T.duplicated()].tolist()

# %%
len(duplicated_columns)
# Out:
# 21

# %%
data = data.drop(duplicated_columns,axis=1)

# %%
data.shape
# Out:
# (2947, 542)

# %%
data.isnull().sum()
# Out:
# tBodyAcc-mean()-X       0
# tBodyAcc-mean()-Y       0
# tBodyAcc-mean()-Z       0
# tBodyAcc-std()-X        0
# tBodyAcc-std()-Y        0
#                        ..
# angle(X,gravityMean)    0
# angle(Y,gravityMean)    0
# angle(Z,gravityMean)    0
# subject                 0
# Activity                0
# Length: 542, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(data['Activity'])
desired_color='green'
plt.xticks(rotation=35,color=desired_color)
plt.show()

# %%
X = data.drop('Activity',axis=1)
y= data['Activity']

# %%
y
# Out:
# 0               STANDING
# 1               STANDING
# 2               STANDING
# 3               STANDING
# 4               STANDING
#               ...
# 2942    WALKING_UPSTAIRS
# 2943    WALKING_UPSTAIRS
# 2944    WALKING_UPSTAIRS
# 2945    WALKING_UPSTAIRS
# 2946    WALKING_UPSTAIRS
# Name: Activity, Length: 2947, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
y
# Out:
# array([2, 2, 2, ..., 5, 5, 5])

# %%
print(globals())
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'import pandas as pd', 'data = pd.read_csv("/content/test.csv.zip")\ndata_test = pd.read_csv("/content/train.csv.zip")', 'data.head()', 'data.tail()', 'data.shape', 'print("Number of Rows",data.shape[0])\nprint("Number of columns",data.shape[1])', 'data.duplicated().any()', 'duplicated_columns = data.columns[data.T.duplicated()].tolist()', 'len(duplicated_columns)', 'data = data.drop(duplicated_columns,axis=1)', 'data.shape', 'data.isnull().sum()', 'import seaborn as sns\nimport matplotlib.pyplot as plt', "sns.countplot(data['Activity'])\nplt.xticks(rotation=35)\nplt.show()", "sns.countplot(data['Activity'])\ndesired_color='green'\nplt.xticks(rotation=35,color=desired_color)\nplt.show()", "X = data.drop('Activity',axis=1)\ny= data['Activity']", 'y', 'from sklearn.preprocessing import LabelEncoder\nle = LabelEncoder()\ny = le.fit_transform(y)', 'y', 'from sklearn.model_selection import train_test_split', 'from sklearn.linear_model import LogisticRegression\nfrom sklearn.metrics import accuracy_score', 'log  = LogisticRegression()\nlog.fit(X_train,y_train)', '# Load the training data from a file or other source\nX_train = ...\ny_train = ...', 'log = LogisticRegression()', 'log.fit(X_train, y_train)', "get_ipython().system('pip install scikit-learn')", 'from sklearn.linear_model import LogisticRegression\nfrom sklearn.metrics import accuracy_score', 'print(type(X_train))\nprint(type(y_train))', 'y_train = [ ... ] # Replace with actual target values', 'log.fit(X_train, y_train)', 'print(globals())'], '_oh': {3:    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
# 2           0.275485          -0.026050          -0.118152         -0.993819
# 3           0.270298          -0.032614          -0.117520         -0.994743
# 4           0.274833          -0.027848          -0.129527         -0.993852
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
# 2         -0.969926         -0.962748         -0.994403         -0.970735
# 3         -0.973268         -0.967091         -0.995274         -0.974471
# 4         -0.967445         -0.978295         -0.994111         -0.965953
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0         -0.674302         -0.894088  ...                        -0.705974
# 1         -0.945823         -0.894088  ...                        -0.594944
# 2         -0.963483         -0.939260  ...                        -0.640736
# 3         -0.968897         -0.938610  ...                        -0.736124
# 4         -0.977346         -0.938610  ...                        -0.846595
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                     0.006462                              0.162920
# 1                    -0.083495                              0.017500
# 2                    -0.034956                              0.202302
# 3                    -0.017067                              0.154438
# 4                    -0.002223                             -0.040046
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                         -0.825886                              0.271151
# 1                         -0.434375                              0.920593
# 2                          0.064103                              0.145068
# 3                          0.340134                              0.296407
# 4                          0.736715                             -0.118545
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  subject  \
# 0             -0.720009              0.276801             -0.057978        2
# 1             -0.698091              0.281343             -0.083898        2
# 2             -0.702771              0.280083             -0.079346        2
# 3             -0.698954              0.284114             -0.077108        2
# 4             -0.692245              0.290722             -0.073857        2
#
#    Activity
# 0  STANDING
# 1  STANDING
# 2  STANDING
# 3  STANDING
# 4  STANDING
#
# [5 rows x 563 columns], 4:       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 2942           0.310155          -0.053391          -0.099109
# 2943           0.363385          -0.039214          -0.105915
# 2944           0.349966           0.030077          -0.115788
# 2945           0.237594           0.018467          -0.096499
# 2946           0.153627          -0.018437          -0.137018
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 2942         -0.287866         -0.140589         -0.215088         -0.356083
# 2943         -0.305388          0.028148         -0.196373         -0.373540
# 2944         -0.329638         -0.042143         -0.250181         -0.388017
# 2945         -0.323114         -0.229775         -0.207574         -0.392380
# 2946         -0.330046         -0.195253         -0.164339         -0.430974
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 2942         -0.148775         -0.232057          0.185361  ...
# 2943         -0.030036         -0.270237          0.185361  ...
# 2944         -0.133257         -0.347029          0.007471  ...
# 2945         -0.279610         -0.289477          0.007471  ...
# 2946         -0.218295         -0.229933         -0.111527  ...
#
#       fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 2942                        -0.750809                    -0.337422
# 2943                        -0.700274                    -0.736701
# 2944                        -0.467179                    -0.181560
# 2945                        -0.617737                     0.444558
# 2946                        -0.436940                     0.598808
#
#       angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 2942                              0.346295                          0.884904
# 2943                             -0.372889                         -0.657421
# 2944                              0.088574                          0.696663
# 2945                             -0.819188                          0.929294
# 2946                             -0.287951                          0.876030
#
#       angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 2942                             -0.698885             -0.651732
# 2943                              0.322549             -0.655181
# 2944                              0.363139             -0.655357
# 2945                             -0.008398             -0.659719
# 2946                             -0.024965             -0.660080
#
#       angle(Y,gravityMean)  angle(Z,gravityMean)  subject          Activity
# 2942              0.274627              0.184784       24  WALKING_UPSTAIRS
# 2943              0.273578              0.182412       24  WALKING_UPSTAIRS
# 2944              0.274479              0.181184       24  WALKING_UPSTAIRS
# 2945              0.264782              0.187563       24  WALKING_UPSTAIRS
# 2946              0.263936              0.188103       24  WALKING_UPSTAIRS
#
# [5 rows x 563 columns], 5: (2947, 563), 7: False, 9: 21, 11: (2947, 542), 12: tBodyAcc-mean()-X       0
# tBodyAcc-mean()-Y       0
# tBodyAcc-mean()-Z       0
# tBodyAcc-std()-X        0
# tBodyAcc-std()-Y        0
#                        ..
# angle(X,gravityMean)    0
# angle(Y,gravityMean)    0
# angle(Z,gravityMean)    0
# subject                 0
# Activity                0
# Length: 542, dtype: int64, 17: 0               STANDING
# 1               STANDING
# 2               STANDING
# 3               STANDING
# 4               STANDING
#               ...
# 2942    WALKING_UPSTAIRS
# 2943    WALKING_UPSTAIRS
# 2944    WALKING_UPSTAIRS
# 2945    WALKING_UPSTAIRS
# 2946    WALKING_UPSTAIRS
# Name: Activity, Length: 2947, dtype: object, 19: array([2, 2, 2, ..., 5, 5, 5])}, '_dh': ['/content'], 'In': ['', 'import pandas as pd', 'data = pd.read_csv("/content/test.csv.zip")\ndata_test = pd.read_csv("/content/train.csv.zip")', 'data.head()', 'data.tail()', 'data.shape', 'print("Number of Rows",data.shape[0])\nprint("Number of columns",data.shape[1])', 'data.duplicated().any()', 'duplicated_columns = data.columns[data.T.duplicated()].tolist()', 'len(duplicated_columns)', 'data = data.drop(duplicated_columns,axis=1)', 'data.shape', 'data.isnull().sum()', 'import seaborn as sns\nimport matplotlib.pyplot as plt', "sns.countplot(data['Activity'])\nplt.xticks(rotation=35)\nplt.show()", "sns.countplot(data['Activity'])\ndesired_color='green'\nplt.xticks(rotation=35,color=desired_color)\nplt.show()", "X = data.drop('Activity',axis=1)\ny= data['Activity']", 'y', 'from sklearn.preprocessing import LabelEncoder\nle = LabelEncoder()\ny = le.fit_transform(y)', 'y', 'from sklearn.model_selection import train_test_split', 'from sklearn.linear_model import LogisticRegression\nfrom sklearn.metrics import accuracy_score', 'log  = LogisticRegression()\nlog.fit(X_train,y_train)', '# Load the training data from a file or other source\nX_train = ...\ny_train = ...', 'log = LogisticRegression()', 'log.fit(X_train, y_train)', "get_ipython().system('pip install scikit-learn')", 'from sklearn.linear_model import LogisticRegression\nfrom sklearn.metrics import accuracy_score', 'print(type(X_train))\nprint(type(y_train))', 'y_train = [ ... ] # Replace with actual target values', 'log.fit(X_train, y_train)', 'print(globals())'], 'Out': {3:    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
# 2           0.275485          -0.026050          -0.118152         -0.993819
# 3           0.270298          -0.032614          -0.117520         -0.994743
# 4           0.274833          -0.027848          -0.129527         -0.993852
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
# 2         -0.969926         -0.962748         -0.994403         -0.970735
# 3         -0.973268         -0.967091         -0.995274         -0.974471
# 4         -0.967445         -0.978295         -0.994111         -0.965953
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0         -0.674302         -0.894088  ...                        -0.705974
# 1         -0.945823         -0.894088  ...                        -0.594944
# 2         -0.963483         -0.939260  ...                        -0.640736
# 3         -0.968897         -0.938610  ...                        -0.736124
# 4         -0.977346         -0.938610  ...                        -0.846595
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                     0.006462                              0.162920
# 1                    -0.083495                              0.017500
# 2                    -0.034956                              0.202302
# 3                    -0.017067                              0.154438
# 4                    -0.002223                             -0.040046
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                         -0.825886                              0.271151
# 1                         -0.434375                              0.920593
# 2                          0.064103                              0.145068
# 3                          0.340134                              0.296407
# 4                          0.736715                             -0.118545
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  subject  \
# 0             -0.720009              0.276801             -0.057978        2
# 1             -0.698091              0.281343             -0.083898        2
# 2             -0.702771              0.280083             -0.079346        2
# 3             -0.698954              0.284114             -0.077108        2
# 4             -0.692245              0.290722             -0.073857        2
#
#    Activity
# 0  STANDING
# 1  STANDING
# 2  STANDING
# 3  STANDING
# 4  STANDING
#
# [5 rows x 563 columns], 4:       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 2942           0.310155          -0.053391          -0.099109
# 2943           0.363385          -0.039214          -0.105915
# 2944           0.349966           0.030077          -0.115788
# 2945           0.237594           0.018467          -0.096499
# 2946           0.153627          -0.018437          -0.137018
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 2942         -0.287866         -0.140589         -0.215088         -0.356083
# 2943         -0.305388          0.028148         -0.196373         -0.373540
# 2944         -0.329638         -0.042143         -0.250181         -0.388017
# 2945         -0.323114         -0.229775         -0.207574         -0.392380
# 2946         -0.330046         -0.195253         -0.164339         -0.430974
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 2942         -0.148775         -0.232057          0.185361  ...
# 2943         -0.030036         -0.270237          0.185361  ...
# 2944         -0.133257         -0.347029          0.007471  ...
# 2945         -0.279610         -0.289477          0.007471  ...
# 2946         -0.218295         -0.229933         -0.111527  ...
#
#       fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 2942                        -0.750809                    -0.337422
# 2943                        -0.700274                    -0.736701
# 2944                        -0.467179                    -0.181560
# 2945                        -0.617737                     0.444558
# 2946                        -0.436940                     0.598808
#
#       angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 2942                              0.346295                          0.884904
# 2943                             -0.372889                         -0.657421
# 2944                              0.088574                          0.696663
# 2945                             -0.819188                          0.929294
# 2946                             -0.287951                          0.876030
#
#       angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 2942                             -0.698885             -0.651732
# 2943                              0.322549             -0.655181
# 2944                              0.363139             -0.655357
# 2945                             -0.008398             -0.659719
# 2946                             -0.024965             -0.660080
#
#       angle(Y,gravityMean)  angle(Z,gravityMean)  subject          Activity
# 2942              0.274627              0.184784       24  WALKING_UPSTAIRS
# 2943              0.273578              0.182412       24  WALKING_UPSTAIRS
# 2944              0.274479              0.181184       24  WALKING_UPSTAIRS
# 2945              0.264782              0.187563       24  WALKING_UPSTAIRS
# 2946              0.263936              0.188103       24  WALKING_UPSTAIRS
#
# [5 rows x 563 columns], 5: (2947, 563), 7: False, 9: 21, 11: (2947, 542), 12: tBodyAcc-mean()-X       0
# tBodyAcc-mean()-Y       0
# tBodyAcc-mean()-Z       0
# tBodyAcc-std()-X        0
# tBodyAcc-std()-Y        0
#                        ..
# angle(X,gravityMean)    0
# angle(Y,gravityMean)    0
# angle(Z,gravityMean)    0
# subject                 0
# Activity                0
# Length: 542, dtype: int64, 17: 0               STANDING
# 1               STANDING
# 2               STANDING
# 3               STANDING
# 4               STANDING
#               ...
# 2942    WALKING_UPSTAIRS
# 2943    WALKING_UPSTAIRS
# 2944    WALKING_UPSTAIRS
# 2945    WALKING_UPSTAIRS
# 2946    WALKING_UPSTAIRS
# Name: Activity, Length: 2947, dtype: object, 19: array([2, 2, 2, ..., 5, 5, 5])}, 'get_ipython': <bound method InteractiveShell.get_ipython of <google.colab._shell.Shell object at 0x7ccdd55c37c0>>, 'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x7ccdd55c2c80>, 'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x7ccdd55c2c80>, '_': array([2, 2, 2, ..., 5, 5, 5]), '__': 0               STANDING
# 1               STANDING
# 2               STANDING
# 3               STANDING
# 4               STANDING
#               ...
# 2942    WALKING_UPSTAIRS
# 2943    WALKING_UPSTAIRS
# 2944    WALKING_UPSTAIRS
# 2945    WALKING_UPSTAIRS
# 2946    WALKING_UPSTAIRS
# Name: Activity, Length: 2947, dtype: object, '___': tBodyAcc-mean()-X       0
# tBodyAcc-mean()-Y       0
# tBodyAcc-mean()-Z       0
# tBodyAcc-std()-X        0
# tBodyAcc-std()-Y        0
#                        ..
# angle(X,gravityMean)    0
# angle(Y,gravityMean)    0
# angle(Z,gravityMean)    0
# subject                 0
# Activity                0
# Length: 542, dtype: int64, '_i': 'log.fit(X_train, y_train)', '_ii': 'y_train = [ ... ] # Replace with actual target values', '_iii': 'print(type(X_train))\nprint(type(y_train))', '_i1': 'import pandas as pd', 'pd': <module 'pandas' from '/usr/local/lib/python3.10/dist-packages/pandas/__init__.py'>, '_i2': 'data = pd.read_csv("/content/test.csv.zip")\ndata_test = pd.read_csv("/content/train.csv.zip")', 'data':       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 
le(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 2942                             -0.698885             -0.651732
# 2943                              0.322549             -0.655181
# 2944                              0.363139             -0.655357
# 2945                             -0.008398             -0.659719
# 2946                             -0.024965             -0.660080
#
#       angle(Y,gravityMean)  angle(Z,gravityMean)  subject          Activity
# 2942              0.274627              0.184784       24  WALKING_UPSTAIRS
# 2943              0.273578              0.182412       24  WALKING_UPSTAIRS
# 2944              0.274479              0.181184       24  WALKING_UPSTAIRS
# 2945              0.264782              0.187563       24  WALKING_UPSTAIRS
# 2946              0.263936              0.188103       24  WALKING_UPSTAIRS
#
# [5 rows x 563 columns], '__js_239': <module 'google.colab.output._js' from '/usr/local/lib/python3.10/dist-packages/google/colab/output/_js.py'>, '_df_0':    index  tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0   2942           0.310155          -0.053391          -0.099109
# 1   2943           0.363385          -0.039214          -0.105915
# 2   2944           0.349966           0.030077          -0.115788
# 3   2945           0.237594           0.018467          -0.096499
# 4   2946           0.153627          -0.018437          -0.137018
#
#    tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0         -0.287866         -0.140589         -0.215088         -0.356083
# 1         -0.305388          0.028148         -0.196373         -0.373540
# 2         -0.329638         -0.042143         -0.250181         -0.388017
# 3         -0.323114         -0.229775         -0.207574         -0.392380
# 4         -0.330046         -0.195253         -0.164339         -0.430974
#
#    tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  ...  tBodyAcc-max()-Y  \
# 0         -0.148775         -0.232057  ...         -0.160309
# 1         -0.030036         -0.270237  ...         -0.035922
# 2         -0.133257         -0.347029  ...         -0.035922
# 3         -0.279610         -0.289477  ...         -0.106078
# 4         -0.218295         -0.229933  ...         -0.078502
#
#    tBodyAcc-max()-Z  tBodyAcc-min()-X  tBodyAcc-min()-Y  tBodyAcc-min()-Z  \
# 0         -0.131106          0.354922          0.188452          0.362922
# 1         -0.131106          0.414650         -0.021580          0.218490
# 2         -0.172677          0.402517         -0.021580          0.218490
# 3         -0.172677          0.357500          0.275632          0.246700
# 4         -0.163373          0.241857          0.168188          0.213778
#
#    tBodyAcc-sma()  tBodyAcc-energy()-X  tBodyAcc-energy()-Y  \
# 0       -0.197803            -0.744913            -0.854291
# 1       -0.186842            -0.755958            -0.794744
# 2       -0.232233            -0.772925            -0.818344
# 3       -0.251372            -0.769266            -0.882274
# 4       -0.236150            -0.771160            -0.874113
#
#    tBodyAcc-energy()-Z  tBodyAcc-iqr()-X
# 0            -0.721311         -0.567761
# 1            -0.708265         -0.549364
# 2            -0.745217         -0.536007
# 3            -0.715982         -0.561646
# 4            -0.683822         -0.616286
#
# [5 rows x 21 columns], '_df_1':    index  tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0   2942           0.310155          -0.053391          -0.099109
# 1   2943           0.363385          -0.039214          -0.105915
# 2   2944           0.349966           0.030077          -0.115788
# 3   2945           0.237594           0.018467          -0.096499
# 4   2946           0.153627          -0.018437          -0.137018
#
#    tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0         -0.287866         -0.140589         -0.215088         -0.356083
# 1         -0.305388          0.028148         -0.196373         -0.373540
# 2         -0.329638         -0.042143         -0.250181         -0.388017
# 3         -0.323114         -0.229775         -0.207574         -0.392380
# 4         -0.330046         -0.195253         -0.164339         -0.430974
#
#    tBodyAcc-mad()-Y  tBodyAcc-mad()-Z
BodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0         -0.287866         -0.140589         -0.215088         -0.356083
# 1         -0.305388          0.028148         -0.196373         -0.373540
# 2         -0.329638         -0.042143         -0.250181         -0.388017
# 3         -0.323114         -0.229775         -0.207574         -0.392380
# 4         -0.330046         -0.195253         -0.164339         -0.430974
#
#    tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  ...  tBodyAcc-max()-Y  \
# 0         -0.148775         -0.232057  ...         -0.160309
# 1         -0.030036         -0.270237  ...         -0.035922
# 2         -0.133257         -0.347029  ...         -0.035922
# 3         -0.279610         -0.289477  ...         -0.106078
# 4         -0.218295         -0.229933  ...         -0.078502
#
#    tBodyAcc-max()-Z  tBodyAcc-min()-X  tBodyAcc-min()-Y  tBodyAcc-min()-Z  \
# 0         -0.131106          0.354922          0.188452          0.362922
# 1         -0.131106          0.414650         -0.021580          0.218490
# 2         -0.172677          0.402517         -0.021580          0.218490
# 3         -0.172677          0.357500          0.275632          0.246700
# 4         -0.163373          0.241857          0.168188          0.213778
#
#    tBodyAcc-sma()  tBodyAcc-energy()-X  tBodyAcc-energy()-Y  \
# 0       -0.197803            -0.744913            -0.854291
# 1       -0.186842            -0.755958            -0.794744
# 2       -0.232233            -0.772925            -0.818344
# 3       -0.251372            -0.769266            -0.882274
# 4       -0.236150            -0.771160            -0.874113
#
#    tBodyAcc-energy()-Z  tBodyAcc-iqr()-X
# 0            -0.721311         -0.567761
# 1            -0.708265         -0.549364
# 2            -0.745217         -0.536007
# 3            -0.715982         -0.561646
# 4            -0.683822         -0.616286
#
# [5 rows x 21 columns], '_df_4':    index  tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0   2942           0.310155          -0.053391          -0.099109
# 1   2943           0.363385          -0.039214          -0.105915
# 2   2944           0.349966           0.030077          -0.115788
# 3   2945           0.237594           0.018467          -0.096499
# 4   2946           0.153627          -0.018437          -0.137018
#
#    tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0         -0.287866         -0.140589         -0.215088         -0.356083
# 1         -0.305388          0.028148         -0.196373         -0.373540
# 2         -0.329638         -0.042143         -0.250181         -0.388017
# 3         -0.323114         -0.229775         -0.207574         -0.392380
# 4         -0.330046         -0.195253         -0.164339         -0.430974
#
#    tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  ...  tBodyAcc-max()-Y  \
# 0         -0.148775         -0.232057  ...         -0.160309
# 1         -0.030036         -0.270237  ...         -0.035922
# 2         -0.133257         -0.347029  ...         -0.035922
# 3         -0.279610         -0.289477  ...         -0.106078
# 4         -0.218295         -0.229933  ...         -0.078502
#
#    tBodyAcc-max()-Z  tBodyAcc-min()-X  tBodyAcc-min()-Y  tBodyAcc-min()-Z  \
# 0         -0.131106          0.354922          0.188452          0.362922
# 1         -0.131106          0.414650         -0.021580          0.218490
# 2         -0.172677          0.402517         -0.021580          0.218490
# 3         -0.172677          0.357500          0.275632          0.246700
# 4         -0.163373          0.241857          0.168188          0.213778
#
#    tBodyAcc-sma()  tBodyAcc-energy()-X  tBodyAcc-energy()-Y  \
# ...
# 4             -0.692245              0.290722             -0.073857        2
#
#    Activity
# 0  STANDING
# 1  STANDING
# 2  STANDING
# 3  STANDING
# 4  STANDING
#
# [5 rows x 563 columns], '_df_30':    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0
# [5 rows x 563 columns], '_i5': 'data.shape', '_5': (2947, 563), '_i6': 'print("Number of Rows",data.shape[0])\nprint("Number of columns",data.shape[1])', '_i7': 'data.duplicated().any()', '_7': False, '_i8': 'duplicated_columns = data.columns[data.T.duplicated()].tolist()', 'duplicated_columns': ['tBodyAccMag-sma()', 'tGravityAccMag-mean()', 'tGravityAccMag-std()', 'tGravityAccMag-mad()', 'tGravityAccMag-max()', 'tGravityAccMag-min()', 'tGravityAccMag-sma()', 'tGravityAccMag-energy()', 'tGravityAccMag-iqr()', 'tGravityAccMag-entropy()', 'tGravityAccMag-arCoeff()1', 'tGravityAccMag-arCoeff()2', 'tGravityAccMag-arCoeff()3', 'tGravityAccMag-arCoeff()4', 'tBodyAccJerkMag-sma()', 'tBodyGyroMag-sma()', 'tBodyGyroJerkMag-sma()', 'fBodyAccMag-sma()', 'fBodyBodyAccJerkMag-sma()', 'fBodyBodyGyroMag-sma()', 'fBodyBodyGyroJerkMag-sma()'], '_i9': 'len(duplicated_columns)', '_9': 21, '_i10': 'data = data.drop(duplicated_columns,axis=1)', '_i11': 'data.shape', '_11': (2947, 542), '_i12': 'data.isnull().sum()', '_12': tBodyAcc-mean()-X       0
# tBodyAcc-mean()-Y       0
# tBodyAcc-mean()-Z       0
# tBodyAcc-std()-X        0
# tBodyAcc-std()-Y        0
#                        ..
# angle(X,gravityMean)    0
# angle(Y,gravityMean)    0
# angle(Z,gravityMean)    0
# subject                 0
# Activity                0
# Length: 542, dtype: int64, '_i13': 'import seaborn as sns\nimport matplotlib.pyplot as plt', 'sns': <module 'seaborn' from '/usr/local/lib/python3.10/dist-packages/seaborn/__init__.py'>, 'plt': <module 'matplotlib.pyplot' from '/usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py'>, '_i14': "sns.countplot(data['Activity'])\nplt.xticks(rotation=35)\nplt.show()", '_i15': "sns.countplot(data['Activity'])\ndesired_color='green'\nplt.xticks(rotation=35,color=desired_color)\nplt.show()", 'desired_color': 'green', '_i16': "X = data.drop('Activity',axis=1)\ny= data['Activity']", 'X':       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.257178          -0.023285          -0.014654
# 1              0.286027          -0.013163          -0.119083
# 2              0.275485          -0.026050          -0.118152
# 3              0.270298          -0.032614          -0.117520
# 4              0.274833          -0.027848          -0.129527
# ...                 ...                ...                ...
# 2942           0.310155          -0.053391          -0.099109
# 2943           0.363385          -0.039214          -0.105915
# 2944           0.349966           0.030077          -0.115788
# 2945           0.237594           0.018467          -0.096499
# 2946           0.153627          -0.018437          -0.137018
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.938404         -0.920091         -0.667683         -0.952501
# 1            -0.975415         -0.967458         -0.944958         -0.986799
# 2            -0.993819         -0.969926         -0.962748         -0.994403
# 3            -0.994743         -0.973268         -0.967091         -0.995274
# 4            -0.993852         -0.967445         -0.978295         -0.994111
# ...                ...               ...               ...               ...
# 2942         -0.287866         -0.140589         -0.215088         -0.356083
# 2943         -0.305388          0.028148         -0.196373         -0.373540
# 2944         -0.329638         -0.042143         -0.250181         -0.388017
# 2945         -0.323114         -0.229775         -0.207574         -0.392380
# 2946         -0.330046         -0.195253         -0.164339         -0.430974
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 0            -0.925249         -0.674302         -0.894088  ...
# 1            -0.968401         -0.945823         -0.894088  ...
# 2            -0.970735         -0.963483         -0.939260  ...
# 3            -0.974471         -0.968897         -0.938610  ...
# 4            -0.965953         -0.977346         -0.938610  ...
# ...                ...               ...               ...  ...
# 2942         -0.148775         -0.232057          0.185361  ...
# 2943         -0.030036         -0.270237          0.185361  ...
# 2944         -0.133257         -0.347029          0.007471  ...
# 2945         -0.279610         -0.289477          0.007471  ...
# 2946         -0.218295         -0.229933         -0.111527  ...
#
#       fBodyBodyGyroJerkMag-skewness()  fBodyBodyGyroJerkMag-kurtosis()  \
# 0                           -0.330370                        -0.705974
# 1                           -0.121845                        -0.594944
# 2                           -0.190422                        -0.640736
# 3                           -0.344418                        -0.736124
# 4                           -0.534685                        -0.846595
# ...                               ...                              ...
# 2942                        -0.376278                        -0.750809
# 2943                        -0.320418                        -0.700274
# 2944                        -0.118854                        -0.467179
# 2945                        -0.205445                        -0.617737
# 2946                        -0.072237                        -0.436940
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                        0.006462                              0.162920
# 1                       -0.083495                              0.017500
# 2                       -0.034956                              0.202302
# 3                       -0.017067                              0.154438
# 4                       -0.002223                             -0.040046
# ...                           ...                                   ...
# 2942                    -0.337422                              0.346295
# 2943                    -0.736701                             -0.372889
# 2944                    -0.181560                              0.088574
# 2945                     0.444558                             -0.819188
# 2946                     0.598808                             -0.287951
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                            -0.825886                              0.271151
# 1                            -0.434375                              0.920593
# 2                             0.064103                              0.145068
# 3                             0.340134                              0.296407
# 4                             0.736715                             -0.118545
# ...                                ...                                   ...
# 2942                          0.884904                             -0.698885
# 2943                         -0.657421                              0.322549
# 2944                          0.696663                              0.363139
# 2945                          0.929294                             -0.008398
# 2946                          0.876030                             -0.024965
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 0                -0.720009              0.276801             -0.057978
# 1                -0.698091              0.281343             -0.083898
# 2                -0.702771              0.280083             -0.079346
# 3                -0.698954              0.284114             -0.077108
# 4                -0.692245              0.290722             -0.073857
# ...                    ...                   ...                   ...
# 2942             -0.651732              0.274627              0.184784
# 2943             -0.655181              0.273578              0.182412
# 2944             -0.655357              0.274479              0.181184
# 2945             -0.659719              0.264782              0.187563
# 2946             -0.660080              0.263936              0.188103
#
#       subject
# 0           2
# 1           2
# 2           2
# 3           2
# 4           2
# ...       ...
# 2942       24
# 2943       24
# 2944       24
# 2945       24
# 2946       24
#
# [2947 rows x 541 columns], 'y': array([2, 2, 2, ..., 5, 5, 5]), '_i17': 'y', '_17': 0               STANDING
# 1               STANDING
# 2               STANDING
# 3               STANDING
# 4               STANDING
#               ...
# 2942    WALKING_UPSTAIRS
# 2943    WALKING_UPSTAIRS
# 2944    WALKING_UPSTAIRS
# 2945    WALKING_UPSTAIRS
# 2946    WALKING_UPSTAIRS
# Name: Activity, Length: 2947, dtype: object, '_i18': 'from sklearn.preprocessing import LabelEncoder\nle = LabelEncoder()\ny = le.fit_transform(y)', 'LabelEncoder': <class 'sklearn.preprocessing._label.LabelEncoder'>, 'le': LabelEncoder(), '_i19': 'y', '_19': array([2, 2, 2, ..., 5, 5, 5]), '_i20': 'from sklearn.model_selection import train_test_split', 'train_test_split': <function train_test_split at 0x7ccd885508b0>, '_i21': 'from sklearn.linear_model import LogisticRegression\nfrom sklearn.metrics import accuracy_score', 'LogisticRegression': <class 'sklearn.linear_model._logistic.LogisticRegression'>, 'accuracy_score': <function accuracy_score at 0x7ccd88553490>, '_i22': 'log  = LogisticRegression()\nlog.fit(X_train,y_train)', 'log': LogisticRegression(), '_i23': '# Load the training data from a file or other source\nX_train = ...\ny_train = ...', 'X_train': Ellipsis, 'y_train': [Ellipsis], '_i24': 'log = LogisticRegression()', '_i25': 'log.fit(X_train, y_train)', '_i26': '!pip install scikit-learn', '_exit_code': 0, '_i27': 'from sklearn.linear_model import LogisticRegression\nfrom sklearn.metrics import accuracy_score', '_i28': 'print(type(X_train))\nprint(type(y_train))', '_i29': 'y_train = [ ... ] # Replace with actual target values', '_i30': 'log.fit(X_train, y_train)', '_i31': 'print(globals())'}

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,
                                               random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
log  = LogisticRegression()
log.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred1 = log.predict(X_test)
accuracy_score(y_test,y_pred1)
# Out:
# 0.9898305084745763

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred2 = rf.predict(X_test)
accuracy_score(y_test,y_pred2)
# Out:
# 0.9830508474576272

# %%
from sklearn.feature_selection import SelectKBest,f_classif

# %%
k=200
selector = SelectKBest(f_classif,k=k)
X_train_selected = selector.fit_transform(X_train,y_train)
X_test_selected = selector.transform(X_test)


selected_indices=selector.get_support(indices=True)
selected_features = X_train.columns[selected_indices]
print(len(selected_features))
# Out:
# 200

# %%
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier

# %%
estimator = RandomForestClassifier()

# %%
k=100
rfe_selector = RFE(estimator,n_features_to_select=k)
X_train_selected_rfe = rfe_selector.fit_transform(X_train_selected,y_train)
X_test_selected_rfe = rfe_selector.transform(X_test_selected)

selected_indices_rfe = rfe_selector.get_support(indices=True)
selected_features_rfe = selected_features[selected_indices_rfe]
print(selected_features_rfe)
# Out:
# Index(['tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-max()-X',
#        'tBodyAcc-sma()', 'tBodyAcc-energy()-X', 'tBodyAcc-iqr()-X',
#        'tBodyAcc-iqr()-Y', 'tBodyAcc-entropy()-X', 'tGravityAcc-mean()-X',
#        'tGravityAcc-max()-X', 'tGravityAcc-min()-X', 'tGravityAcc-energy()-X',
#        'tGravityAcc-energy()-Y', 'tBodyAccJerk-std()-X',
#        'tBodyAccJerk-std()-Y', 'tBodyAccJerk-std()-Z', 'tBodyAccJerk-mad()-X',
#        'tBodyAccJerk-mad()-Y', 'tBodyAccJerk-max()-X', 'tBodyAccJerk-sma()',
#        'tBodyAccJerk-entropy()-X', 'tBodyGyro-std()-X', 'tBodyGyro-std()-Y',
#        'tBodyGyro-std()-Z', 'tBodyGyro-mad()-X', 'tBodyGyro-mad()-Y',
#        'tBodyGyro-mad()-Z', 'tBodyGyro-max()-X', 'tBodyGyro-max()-Z',
#        'tBodyGyro-min()-X', 'tBodyGyro-sma()', 'tBodyGyro-iqr()-X',
#        'tBodyGyro-iqr()-Y', 'tBodyGyro-iqr()-Z', 'tBodyGyroJerk-std()-X',
#        'tBodyGyroJerk-mad()-X', 'tBodyGyroJerk-mad()-Y',
#        'tBodyGyroJerk-max()-X', 'tBodyGyroJerk-sma()', 'tBodyGyroJerk-iqr()-X',
#        'tBodyAccMag-std()', 'tBodyAccMag-mad()', 'tBodyAccMag-max()',
#        'tBodyAccJerkMag-mean()', 'tBodyAccJerkMag-mad()',
#        'tBodyAccJerkMag-energy()', 'tBodyAccJerkMag-iqr()',
#        'tBodyAccJerkMag-entropy()', 'tBodyGyroMag-mean()',
#        'tBodyGyroMag-energy()', 'tBodyGyroJerkMag-mad()', 'fBodyAcc-std()-X',
#        'fBodyAcc-std()-Y', 'fBodyAcc-std()-Z', 'fBodyAcc-mad()-Y',
#        'fBodyAcc-mad()-Z', 'fBodyAcc-max()-X', 'fBodyAcc-max()-Y',
#        'fBodyAcc-max()-Z', 'fBodyAcc-energy()-X', 'fBodyAcc-bandsEnergy()-1,8',
#        'fBodyAcc-bandsEnergy()-1,16', 'fBodyAcc-bandsEnergy()-1,24',
#        'fBodyAccJerk-mean()-Y', 'fBodyAccJerk-std()-X', 'fBodyAccJerk-std()-Y',
#        'fBodyAccJerk-std()-Z', 'fBodyAccJerk-mad()-Y', 'fBodyAccJerk-max()-X',
#        'fBodyAccJerk-max()-Y', 'fBodyAccJerk-max()-Z', 'fBodyAccJerk-sma()',
#        'fBodyAccJerk-bandsEnergy()-1,8', 'fBodyAccJerk-bandsEnergy()-1,16',
#        'fBodyAccJerk-bandsEnergy()-1,24', 'fBodyGyro-mean()-X',
#        'fBodyGyro-mean()-Y', 'fBodyGyro-mean()-Z', 'fBodyGyro-std()-X',
#        'fBodyGyro-std()-Y', 'fBodyGyro-std()-Z', 'fBodyGyro-mad()-X',
#        'fBodyGyro-mad()-Y', 'fBodyGyro-max()-X', 'fBodyGyro-max()-Y',
#        'fBodyGyro-max()-Z', 'fBodyGyro-entropy()-X', 'fBodyAccMag-mean()',
#        'fBodyAccMag-std()', 'fBodyAccMag-mad()', 'fBodyAccMag-max()',
#        'fBodyAccMag-energy()', 'fBodyBodyAccJerkMag-std()',
#        'fBodyBodyAccJerkMag-max()', 'fBodyBodyGyroMag-std()',
#        'fBodyBodyGyroJerkMag-max()', 'angle(X,gravityMean)'],
#       dtype='object')

# %%
print(len(selected_features_rfe))
# Out:
# 100

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train_selected_rfe,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_rf = rf.predict(X_test_selected_rfe)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred_rf)
# Out:
# 0.9610169491525423

# %%
import joblib

# %%
joblib.dump(rf,"model_rfe")
# Out:
# ['model_rfe']

# %%
joblib.dump(selector,"k_best_selector")
# Out:
# ['k_best_selector']

# %%
joblib.dump(rfe_selector,"rfe_selector")
# Out:
# ['rfe_selector']

# %%
data_test=data_test.drop("Activity",axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-143-6ab6f0908aa9> in <cell line: 1>()
# ----> 1 data_test=data_test.drop("Activity",axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4589                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4590             else:
# -> 4591                 new_axis = axis.drop(labels, errors=errors)
#    4592             indexer = axis.get_indexer(new_axis)
#    4593
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6697         if mask.any():
#    6698             if errors != "ignore":
# -> 6699                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700             indexer = indexer[~mask]
#    6701         return self.delete(indexer)
#
# KeyError: "['Activity'] not found in axis"

# %%
duplicated_columns = data_test.columns[data_test.T.duplicated()].to_list()

# %%
data_test = data_test.drop(duplicated_columns,axis=1)

# %%
model = joblib.load('model_rfe')

# %%
selector = joblib.load('k_best_selector')

# %%
rfe_selector = joblib.load('rfe_selector')

# %%
selector=selector.transform(data_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-136-c76191ba20ff> in <cell line: 1>()
# ----> 1 selector=selector.transform(data_test)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'transform'

# %%
X_test_selected_rfe = rfe_selector.transform(selector)

# %%
model.predict(X_test_selected_rfe)
# Out:
# array([2, 2, 2, ..., 5, 5, 5])

# %%
import tkinter as tk
from tkinter import filedialog
import pandas as pd
import joblib
from tkinter import messagebox

def open_file():
    filepath=filedialog.askopenfile(filetypes=[("CSV Files",".csv")])
    if filepath:
        try:
            data=pd.read_csv(filepath)
            process_data(data)
        except Exception as e:
            messagebox.showerror("Error",f"Failed to open file {e}")

def process_data(data):
    # Find columns with the same values
    #data= data.drop("Activity",axis=1)
    duplicated_columns = data.columns[data.T.duplicated()].tolist()
    # Remove columns with the same values

    data_test = data.drop(duplicated_columns, axis=1)

    model = joblib.load("model_rfe")
    # Load the SelectKBest object from the file
    selector = joblib.load('k_best_selector')
    rfe_selector = joblib.load('rfe_selector')

    # Transform the new data using the loaded SelectKBest object
    X_test_selected = selector.transform(data_test)

    # Transform the new data using the loaded RFE object
    X_test_selected_rfe = rfe_selector.transform(X_test_selected)
    y_pred=model.predict(X_test_selected_rfe)
    # standing : 0, sitting : 1,laying : 2, WALKING_DOWNSTAIRS: 3,
    # walking_upstairs:4,walking : 5
    y_pred = pd.Series(y_pred)
    y_pred = y_pred.map({0: 'Standing',1:'Sitting',2:'Laying',
                        3: 'Walking_downstairs',4: 'Walking_upstairs',
                        5:"Walking"})
    data['Predicted_target']=y_pred
    save_file(data)

def save_file(data):
    savepath=filedialog.asksaveasfilename(defaultextension=".csv",
                              filetypes=[("CSV Files",".csv")])
    if savepath:
        try:
            data.to_csv(savepath)
            messagebox.showinfo("Success","File Saved Successfully")
        except Exception as e:
            messagebox.showerror("Error",f"Failed to save file:{e}")


# Create a Tkinter GUI

root = tk.Tk()

root.title("Classification")

root.geometry("200x200")

button1 = tk.Button(root,text="Open CSV File",
                   width=15,
                   height=2,
                   background="lightgreen",
                   activebackground="lightblue",
                   font=("Arial",11,"bold"),
                   command=open_file)

button1.pack(pady=50)

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-130-ae42b48be107> in <cell line: 57>()
#      55 # Create a Tkinter GUI
#      56
# ---> 57 root = tk.Tk()
#      58
#      59 root.title("Classification")
#
# /usr/lib/python3.10/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2297                 baseName = baseName + ext
#    2298         interactive = False
# -> 2299         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2300         if useTk:
#    2301             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable
